# %%
from ultralytics import YOLO
import ipfs_api
import os

# %%
model = YOLO("yolov8l.pt")  # load a pretrained model (recommended for training)

# %%
IMG_CID = "QmcCb3RUymcTSAXtFAbTkjY86L1XLfpUVjmaiGCVs2phX5"

ipfs_api.download(IMG_CID, 'input.png')
results = model("input.png")  # predict on an image
# Out:
# image 1/1 /Users/stevengong/Projects/vision.dev/flask-app/input.png: 640x480 1 person, 1 train, 1 stop sign, 476.2ms
# Speed: 1.6ms preprocess, 476.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)

# %%
import cv2
import numpy as np
from PIL import Image

# Get the image as a numpy array in BGR format
img_bgr = results[0].plot()

# Convert the image from BGR to RGB
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

# Convert the numpy array to a PIL image
img_pil = Image.fromarray(img_rgb)
img_pil
# Out:
# <PIL.Image.Image image mode=RGB size=480x640>

# %%
# Save the image as a PNG file
img_pil.save("output.png")
